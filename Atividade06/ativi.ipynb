# %%
import pandas as pd
import xlrd

# %%
path = r"H:\Python\Atividade06\Tabela5-sem_emprego_2012.csv"
path2 = r"H:\Python\Atividade06\Tabela5-sem_emprego_2026.csv"
path3 = r"H:\Python\Atividade06\Tabela 1.1.1.xls"

# %%
t2012 = pd.read_csv(path, sep=";", encoding="utf-8-sig")
t2026 = pd.read_csv(path2, sep=";", encoding="utf-8-sig")

# %%
t2012
# Out:
#    Sigla  Código               Estado Desocupados - homens (2012 T1)  \
# 0     AC      12                 Acre                           45,3
# 1     AL      27              Alagoas                           44,7
# 2     AM      13             Amazonas                           47,5
# 3     AP      16                Amapá                           48,1
# 4     BA      29                Bahia                           43,8
# 5     CE      23                Ceará                           51,1
# 6     DF      53     Distrito Federal                             41
# 7     ES      32       Espírito Santo                           46,4
# 8     GO      52                Goiás                             41
# 9     MA      21             Maranhão                           47,2
# 10    MG      31         Minas Gerais                           43,1
# 11    MS      50   Mato Grosso do Sul                           47,2
# 12    MT      51          Mato Grosso                           44,1
# ...

# %%
comp = t2012.merge(t2026, on=["Sigla", "Código", "Estado"], how="inner")

# %%
comp
# Out:
#    Sigla  Código               Estado Desocupados - homens (2012 T1)  \
# 0     AC      12                 Acre                           45,3
# 1     AL      27              Alagoas                           44,7
# 2     AM      13             Amazonas                           47,5
# 3     AP      16                Amapá                           48,1
# 4     BA      29                Bahia                           43,8
# 5     CE      23                Ceará                           51,1
# 6     DF      53     Distrito Federal                             41
# 7     ES      32       Espírito Santo                           46,4
# 8     GO      52                Goiás                             41
# 9     MA      21             Maranhão                           47,2
# 10    MG      31         Minas Gerais                           43,1
# 11    MS      50   Mato Grosso do Sul                           47,2
# 12    MT      51          Mato Grosso                           44,1
# ...

# %%
tIBGE = pd.read_excel(path3, engine="xlrd", header=5)
tIBGE
# Out:
#                                            Unnamed: 0      Total  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                              Brasil  16.985781
# 3                                               Norte  16.187037
# 4                                            Rondônia  17.014162
# 5                                                Acre  13.606903
# 6                                            Amazonas  16.807290
# 7                                             Roraima  13.639257
# 8                                                Pará  16.474268
# 9                                               Amapá  13.586656
# 10                                          Tocantins  15.815781
# 11                                           Nordeste  18.499396
# 12                                           Maranhão  16.669614
# ...

# %%
juntado =  comp.merge(tIBGE, on=["Sigla", "Código", "Estado"], how="inner")
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 juntado =  comp.merge(tIBGE, how="inner")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:12902, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   12898 self._check_copy_deprecation(copy)
#   12900 from pandas.core.reshape.merge import merge
# > 12902 return merge(
#   12903     self,
#   12904     right,
#   12905     how=how,
#   12906     on=on,
#   12907     left_on=left_on,
#   12908     right_on=right_on,
#   12909     left_index=left_index,
#   12910     right_index=right_index,
#   12911     sort=sort,
#   12912     suffixes=suffixes,
#   12913     indicator=indicator,
#   12914     validate=validate,
#   12915 )
#
# ...
